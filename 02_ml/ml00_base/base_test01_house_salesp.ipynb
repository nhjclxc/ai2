# %% [markdown]
# # 分析house_salesp.csv数据集
#
# 1. 数据采集
# 2. 确定分析方向
# 3. 导入数据
# 4. 数据清洗
# 5. 新特征构造
# 6. 数据分析
# 7. 数据可视化

# %%
import numpy as np
import pandas as pd
# import matplotlib
import matplotlib.pyplot as plt
print(np.__version__)
print(pd.__version__)
# print(matplotlib.__version__)
# 显示中文问题
plt.rcParams['font.sans-serif'] = ['SimHei']      # 使用黑体
plt.rcParams['axes.unicode_minus'] = False        # 解决负号显示问题
# Out:
# 2.2.5
# 2.3.3

# %%
# 1. 数据采集
df = pd.read_csv('../../data/ml/base/house_sales.csv')
# df.info

# %%
# 2. 确定分析方向
# 2.1 哪些变量最影响房价?面积\楼层\房间数这几个哪个影响更大
# 2.2 全国房价总体分布是怎么样的?是否存在极端值
# 2.3 哪些城市房价最高?直辖市与非直辖市的差异如何
# 2.4 高价房在面积楼层方面有什么特征?
# 2.5 那种户型最受欢迎?三室比两室贵多少?
# 2.6 南北向是否真的比单一朝向更贵?贵多少?
# 2.7 新放比10年老房贵多少?折旧规律如何?



# 3. 导入数据

# %%
# 4. 数据清洗

# 4.1删除无用的链接那一列 origin_url
df.drop(columns=['origin_url'], inplace=True)

# %%
# 4.2 数据类型转化
print(df.info())
print(df.head())
df['area'] = df['area'].apply(lambda x: x.replace('㎡', '')).astype('int')  # 90㎡ -> 90
# df['price'] = df['price'].apply(lambda x : x.replace('万', '')).astype('int')  #  128万 -> 128
# df['unit'] = df['unit'].apply(lambda x : x.replace('元/㎡', '')).astype('int')  #  13895元/㎡ -> 13895
# df['year'] = df['year'].apply(lambda x : x.replace('年建', '')).astype('int')  #  2019年建 -> 2019
# df['rooms'] = df['rooms'].astype('category')
# df['toward'] = df['toward'].astype('category')
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3000 non-null   int64
#  1   city        3000 non-null   object
#  2   address     2966 non-null   object
#  3   area        2974 non-null   object
#  4   floor       2736 non-null   object
#  5   name        2974 non-null   object
#  6   price       2974 non-null   object
#  7   province    3000 non-null   object
#  8   rooms       2736 non-null   object
#  9   toward      2956 non-null   object
#  10  unit        2974 non-null   object
#  11  year        2202 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 281.4+ KB
# None
#    Unnamed: 0 city              address area     floor    name price province  \
# 0           0   合肥   龙岗-临泉东路和王岗大道交叉口东南角  90㎡  中层（共18层）    圣地亚哥  128万       安徽
# ...

# %%
# 4.2 缺失值处理
print(df.isna().sum())
# 用unknow来填充缺失值地址
# df['address'] = df['address'].fillna('unknow')
# area 用平均值填充
print(df['area'].mean())
# df['area'] = df['area'].fillna('')
print(df.isna().sum())

df.info()
# 5. 新特征构造
# 6. 数据分析
# 7. 数据可视化
